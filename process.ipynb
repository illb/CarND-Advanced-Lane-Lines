# %% [markdown]
# ## 01 camera calibration

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import camera_calibration as cc

objpoints, imgpoints = cc.find_corners()
cc.save_corners(objpoints, imgpoints)
# Out:
# started finding chessboard : ./camera_cal/calibration1.jpg
# finished finding chessboard : ./camera_cal/calibration1.jpg, success=False
# started finding chessboard : ./camera_cal/calibration2.jpg
# finished finding chessboard : ./camera_cal/calibration2.jpg, success=True
# started finding chessboard : ./camera_cal/calibration3.jpg
# finished finding chessboard : ./camera_cal/calibration3.jpg, success=True
# started finding chessboard : ./camera_cal/calibration4.jpg
# finished finding chessboard : ./camera_cal/calibration4.jpg, success=False
# started finding chessboard : ./camera_cal/calibration5.jpg
# finished finding chessboard : ./camera_cal/calibration5.jpg, success=False
# started finding chessboard : ./camera_cal/calibration6.jpg
# finished finding chessboard : ./camera_cal/calibration6.jpg, success=True
# started finding chessboard : ./camera_cal/calibration7.jpg
# finished finding chessboard : ./camera_cal/calibration7.jpg, success=True
# started finding chessboard : ./camera_cal/calibration8.jpg
# finished finding chessboard : ./camera_cal/calibration8.jpg, success=True
# started finding chessboard : ./camera_cal/calibration9.jpg
# finished finding chessboard : ./camera_cal/calibration9.jpg, success=True
# started finding chessboard : ./camera_cal/calibration10.jpg
# finished finding chessboard : ./camera_cal/calibration10.jpg, success=True
# started finding chessboard : ./camera_cal/calibration11.jpg
# finished finding chessboard : ./camera_cal/calibration11.jpg, success=True
# started finding chessboard : ./camera_cal/calibration12.jpg
# finished finding chessboard : ./camera_cal/calibration12.jpg, success=True
# started finding chessboard : ./camera_cal/calibration13.jpg
# finished finding chessboard : ./camera_cal/calibration13.jpg, success=True
# started finding chessboard : ./camera_cal/calibration14.jpg
# finished finding chessboard : ./camera_cal/calibration14.jpg, success=True
# started finding chessboard : ./camera_cal/calibration15.jpg
# finished finding chessboard : ./camera_cal/calibration15.jpg, success=True
# started finding chessboard : ./camera_cal/calibration16.jpg
# finished finding chessboard : ./camera_cal/calibration16.jpg, success=True
# started finding chessboard : ./camera_cal/calibration17.jpg
# finished finding chessboard : ./camera_cal/calibration17.jpg, success=True
# started finding chessboard : ./camera_cal/calibration18.jpg
# finished finding chessboard : ./camera_cal/calibration18.jpg, success=True
# started finding chessboard : ./camera_cal/calibration19.jpg
# finished finding chessboard : ./camera_cal/calibration19.jpg, success=True
# started finding chessboard : ./camera_cal/calibration20.jpg
# finished finding chessboard : ./camera_cal/calibration20.jpg, success=True

# %% [markdown]
# ## 02  Distrotion Correction

# %% [markdown]
# ## 03 Color & Gradient threshold

# %% [markdown]
# ## 04 Perspective Transform

# %%
import cv2
import numpy as np
import os
import data

def undist(objpoints, imgpoints):
    fnames = []

    for fname in data.get_test_paths():
        img = cv2.imread(fname)
        dst = cc.undistort_with_corners(img, objpoints, imgpoints)
        outname = './debug/undistorted_' + os.path.basename(fname)
        cv2.imwrite(outname, dst)
        print("undistort_calibration : {}".format(outname))

objpoints, imgpoints = cc.load_corners()
undist(objpoints, imgpoints)
        
img = mpimg.imread('./test_images/test1.jpg')
undistorted = cc.undistort_with_corners(img, objpoints, imgpoints)
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(24, 9))
f.tight_layout()
ax1.imshow(img)
ax1.set_title('Original Image', fontsize=50)
ax2.imshow(undistorted)
ax2.set_title('Undistorted Image', fontsize=50)
plt.subplots_adjust(left=0., right=1, top=0.9, bottom=0.)
# Out:
# undistort_calibration : ./debug/undistorted_test1.jpg
# undistort_calibration : ./debug/undistorted_test2.jpg
# undistort_calibration : ./debug/undistorted_test3.jpg
# undistort_calibration : ./debug/undistorted_test4.jpg
# undistort_calibration : ./debug/undistorted_test5.jpg
# undistort_calibration : ./debug/undistorted_test6.jpg

# %% [markdown]
# ## result

# %%
plt.figure(figsize=(20,10))
paths = data.get_test_paths()
for i in range(6):
    fname = paths[i]
    img = cv2.imread(fname)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.subplot(2, 3, i+1)
    plt.imshow(img)
    plt.title(os.path.basename(fname))
plt.show()
